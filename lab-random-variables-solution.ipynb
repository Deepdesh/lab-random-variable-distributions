# %% [markdown]
# Refer to the files_for_lab/we_fn_use_c_marketing_customer_value_analysis.csv dataset.
#
# Instructions
#
# Get the numerical variables from our dataset.
# Check using a distribution plot if the variables fit the theoretical normal or exponential distribution.
# Check if any of the transformations (log-transform, etc.) we have seen up to this point changes the result.

# %%
# To make run all you ask in one cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# 1. Get the numerical variables from our dataset.

# %%
import pandas as pd
import numpy as np

#additional libraries
import time
from datetime import time
from datetime import datetime
from datetime import timedelta

# %%
data = pd.read_csv('/Users/deshdeepak/ironhack/lab-random-variable-distributions/files_for_lab/we_fn_use_c_marketing_customer_value_analysis.csv')
data.head(5)
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# ...

# %%
data['Effective To Date']= pd.to_datetime(data['Effective To Date'])
data.info()
#df['Date']= pd.to_datetime(df['Date'])
numerical_df = data.select_dtypes(np.number)
numerical_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer                       9134 non-null   object
#  1   State                          9134 non-null   object
#  2   Customer Lifetime Value        9134 non-null   float64
#  3   Response                       9134 non-null   object
#  4   Coverage                       9134 non-null   object
#  5   Education                      9134 non-null   object
#  6   Effective To Date              9134 non-null   datetime64[ns]
#  7   EmploymentStatus               9134 non-null   object
#  8   Gender                         9134 non-null   object
#  9   Income                         9134 non-null   int64
#  10  Location Code                  9134 non-null   object
#  11  Marital Status                 9134 non-null   object
# ...

# %% [markdown]
# 2. Check using a distribution plot if the variables fit the theoretical normal or exponential distribution.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
col_names = numerical_df.columns.tolist()
for i in range(len(col_names)):
        plt.hist(numerical_df.iloc[:,i],bins=20)
        print('for variable',col_names[i])
        plt.show()

print('for effective to date:')
plt.hist(data['Effective To Date'],bins=20)
plt.show()
# Out:
# for variable Customer Lifetime Value
# for variable Income
# for variable Monthly Premium Auto
# for variable Months Since Last Claim
# for variable Months Since Policy Inception
# for variable Number of Open Complaints
# for variable Number of Policies
# for variable Total Claim Amount
# for effective to date:

# %%
for i in range(len(col_names)):
        sns.distplot(numerical_df.iloc[:,i])
        print('for variable',col_names[i])
        plt.show()

        
print('for Effective To Date:   ')
sns.distplot(data['Effective To Date'])
# Out:
# /usr/local/Cellar/jupyterlab/3.0.12/libexec/lib/python3.9/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# for variable Customer Lifetime Value
# /usr/local/Cellar/jupyterlab/3.0.12/libexec/lib/python3.9/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# for variable Income
# ...

# %%
numerical_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer Lifetime Value        9134 non-null   float64
#  1   Income                         9134 non-null   int64
#  2   Monthly Premium Auto           9134 non-null   int64
#  3   Months Since Last Claim        9134 non-null   int64
#  4   Months Since Policy Inception  9134 non-null   int64
#  5   Number of Open Complaints      9134 non-null   int64
#  6   Number of Policies             9134 non-null   int64
#  7   Total Claim Amount             9134 non-null   float64
# dtypes: float64(2), int64(6)
# memory usage: 571.0 KB

# %%
numerical_df.isnull().sum()/len(numerical_df)
# Out:
# Customer Lifetime Value          0.0
# Income                           0.0
# Monthly Premium Auto             0.0
# Months Since Last Claim          0.0
# Months Since Policy Inception    0.0
# Number of Open Complaints        0.0
# Number of Policies               0.0
# Total Claim Amount               0.0
# dtype: float64

# %%
#no null values

# %% [markdown]
# 0   **Customer Lifetime Value:**
#
# Type: Exponential distribution
#
# 1   **Income:**
#
# Type: Exponential distribution
#
# 2   **Monthly Premium Auto:**
#
# Type: Exponential distribution
#
# 3   **Months Since Last Claim:**
#
# Type: Exponential distribution
#
# 4   **Months Since Policy Inception:**
#
# Type: Uniform distribution
#
# 5   **Number of Open Complaints:**
#
# Type: Exponential distribution
#
# 6   **Number of Policies:**
#
# Type: Exponential distribution
#
# 7   **Total Claim Amount:**
#
# Type: Exponential distribution
#
# 8   **Effective to Date:**
#
# Type: Uniform Distribution

# %% [markdown]
# 3. Check if any of the transformations (log-transform, etc.) we have seen up to this point changes the result.

# %%
def log_transform_clean(row):
    if np.isfinite(row) and row!=0:
        return np.log(row)
    else:
        return row

# %%
numerical_dfc = numerical_df


def apply_log_trans(df):
    col_names_c = df.columns.tolist()
    for i in range(len(col_names_c)):
        #display(pd.Series(df.iloc[:,i].apply(log_transform_clean)).hist())
        #plt.show()
        df = pd.Series(df.iloc[:,i].apply(log_transform_clean))
        return df
def plot_log_trans(df):
    col_names_c = df.columns.tolist()
    for i in range(len(col_names_c)):
        print('for variable',col_names_c[i])
        display(pd.Series(df.iloc[:,i].apply(log_transform_clean)).hist())
        plt.show()

# %%
apply_log_trans(numerical_dfc)
plot_log_trans(numerical_dfc)
# Out:
# 0        7.924260
# 1        8.850738
# 2        9.464008
# 3        8.941920
# 4        7.942253
#           ...
# 9129    10.060747
# 9130     8.038031
# 9131     9.007476
# 9132     8.925912
# 9133     7.867809
# Name: Customer Lifetime Value, Length: 9134, dtype: float64
# for variable Customer Lifetime Value
# <AxesSubplot:>
# for variable Income
# <AxesSubplot:>
# for variable Monthly Premium Auto
# <AxesSubplot:>
# for variable Months Since Last Claim
# <AxesSubplot:>
# for variable Months Since Policy Inception
# <AxesSubplot:>
# for variable Number of Open Complaints
# <AxesSubplot:>
# for variable Number of Policies
# <AxesSubplot:>
# for variable Total Claim Amount
# <AxesSubplot:>

# %% [markdown]
# Observation: Applying log transformation we see it was not beneficial for all of them. Caveat: Customer Lifetime Value and Total Claim Amount variables are now transformed and follow normal distribution. But it did not work for all of them.

# %%
#now checking with MinMaxScaler

from sklearn.preprocessing import MinMaxScaler

numerical_dfc1 = pd.DataFrame(MinMaxScaler().fit_transform(numerical_df), columns=numerical_df.columns)
numerical_dfc1.head(5)
# Out:
#    Customer Lifetime Value    Income  Monthly Premium Auto  \
# 0                 0.010629  0.562847              0.033755
# 1                 0.062406  0.000000              0.139241
# 2                 0.134960  0.487763              0.198312
# 3                 0.070589  0.000000              0.189873
# 4                 0.011245  0.438443              0.050633
#
#    Months Since Last Claim  Months Since Policy Inception  \
# 0                 0.914286                       0.050505
# 1                 0.371429                       0.424242
# 2                 0.514286                       0.383838
# 3                 0.514286                       0.656566
# 4                 0.342857                       0.444444
#
#    Number of Open Complaints  Number of Policies  Total Claim Amount
# 0                        0.0               0.000            0.132974
# 1                        0.0               0.875            0.391051
# ...

# %%
col_names_c1 = numerical_dfc1.columns.tolist()
for i in range(len(col_names_c1)):
        sns.distplot(numerical_df.iloc[:,i])
        print('for variable',col_names_c1[i])
        plt.show()
# Out:
# /usr/local/Cellar/jupyterlab/3.0.12/libexec/lib/python3.9/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Customer Lifetime Value', ylabel='Density'>
# for variable Customer Lifetime Value
# /usr/local/Cellar/jupyterlab/3.0.12/libexec/lib/python3.9/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Income', ylabel='Density'>
# for variable Income
# ...

# %% [markdown]
# No significant different observed. Perhaps, removing outliers would help. Trying that out in next step.

# %%
def plot_box(df):
    col_names_c = df.columns.tolist()
    for i in range(len(col_names_c)):
        print('for variable',col_names_c[i])
        sns.boxplot(df.iloc[:,i])
        plt.show()
        
plot_box(numerical_dfc1)
# Out:
# for variable Customer Lifetime Value
# /usr/local/Cellar/jupyterlab/3.0.12/libexec/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# for variable Income
# /usr/local/Cellar/jupyterlab/3.0.12/libexec/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# for variable Monthly Premium Auto
# ...

# %%
        
def remove_outlier(df):
    col_names_co = df.columns.tolist()
    for i in range(len(col_names_co)):

        iqr = np.percentile(df.iloc[:,i],75) - np.percentile(df.iloc[:,i],25)
        #iqr = np.percentile(df.['income'],75) - np.percentile(df.['income'],25)
        upper_limit = np.percentile(df.iloc[:,i],75) + 1.5*iqr
        
        extraordinary_points = df[df.iloc[:,i]>upper_limit]
        #len(extraordinary_points)
        df=df[df.iloc[:,i]<upper_limit]
        return df

# %%
numerical_dfc2 = numerical_df
#apply_log_trans(numerical_dfc2)
remove_outlier(numerical_dfc2)
plot_log_trans(numerical_dfc2)
# Out:
#       Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0                 2763.519279   56274                    69
# 1                 6979.535903       0                    94
# 2                12887.431650   48767                   108
# 3                 7645.861827       0                   106
# 4                 2813.692575   43836                    73
# ...                       ...     ...                   ...
# 9128              4100.398533   47761                   104
# 9130              3096.511217   21604                    79
# 9131              8163.890428       0                    85
# 9132              7524.442436   21941                    96
# 9133              2611.836866       0                    77
#
#       Months Since Last Claim  Months Since Policy Inception  \
# 0                          32                              5
# 1                          13                             42
# ...

# %%
numerical_dfc3 = numerical_df
#apply_log_trans(numerical_dfc2)
remove_outlier(numerical_dfc3)
plot_log_trans(numerical_dfc3)
# Out:
#       Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0                 2763.519279   56274                    69
# 1                 6979.535903       0                    94
# 2                12887.431650   48767                   108
# 3                 7645.861827       0                   106
# 4                 2813.692575   43836                    73
# ...                       ...     ...                   ...
# 9128              4100.398533   47761                   104
# 9130              3096.511217   21604                    79
# 9131              8163.890428       0                    85
# 9132              7524.442436   21941                    96
# 9133              2611.836866       0                    77
#
#       Months Since Last Claim  Months Since Policy Inception  \
# 0                          32                              5
# 1                          13                             42
# ...

# %% [markdown]
# From these observations, it is clear that applying same kind of transformations or cleaning processes don't work for each of these variables in the intended way. Perhaps, it is better to apply different ones for different variables. For instance, removing outliers seems to have turned 'Total Claim Amount' into a normal distribution but it didn't work for others.
